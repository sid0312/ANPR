# %% [markdown]
# <a href="https://colab.research.google.com/github/sid0312/ANPR/blob/master/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-06-09 19:09:18--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   237KB/s    in 10m 7s
#
# 2020-06-09 19:19:27 (261 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls -la "/content/gdrive/My Drive/darknet"
# Out:
# total 12
# drwx------ 2 root root 4096 Jun  9 19:40 bin
# drwx------ 2 root root 4096 Sep  8  2019 cudNN
# drwx------ 2 root root 4096 Jun  9 19:40 .ipynb_checkpoints

# %%
# !sudo apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 32 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (816 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# ...

# %%
# !tree /content/gdrive/My\ Drive/darknet/
# Out:
# /content/gdrive/My Drive/darknet/
# ├── bin
# │   └── darknet
# │       └── darknet
# │           ├── 3rdparty
# │           │   ├── pthreads
# │           │   │   ├── bin
# │           │   │   │   ├── pthreadGC2.dll
# │           │   │   │   └── pthreadVC2.dll
# │           │   │   ├── include
# │           │   │   │   ├── pthread.h
# │           │   │   │   ├── sched.h
# │           │   │   │   └── semaphore.h
# │           │   │   └── lib
# │           │   │       ├── libpthreadGC2.a
# │           │   │       └── pthreadVC2.lib
# │           │   └── stb
# │           │       └── include
# │           │           ├── stb_image.h
# │           │           └── stb_image_write.h
# │           ├── appveyor.yml
# │           ├── backup
# │           ├── build
# │           │   └── darknet
# │           │       ├── darknet_no_gpu.sln
# │           │       ├── darknet_no_gpu.vcxproj
# │           │       ├── darknet.sln
# │           │       ├── darknet.vcxproj
# ...

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !tar -xzvf /content/gdrive/My\ Drive/darknet/cudNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a

# %%
# !chmod a+r /usr/local/cuda/include/cudnn.h

# %%
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.14 MiB | 10.71 MiB/s, done.
# Resolving deltas: 100% (6735/6735), done.
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md

# %%
# !git checkout feature/google-colab
# Out:
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ...

# %%
# !pwd
# Out:
# /content/darknet

# %%
cd ..
# Out:
# /content

# %%
# !mkdir an-pr

# %%
cd an-pr
# Out:
# /content/an-pr

# %%
# !git clone https://github.com/sid0312/ANPR
# Out:
# Cloning into 'ANPR'...
# remote: Enumerating objects: 553, done.
# remote: Counting objects: 100% (553/553), done.
# remote: Compressing objects: 100% (539/539), done.
# remote: Total 553 (delta 32), reused 485 (delta 2), pack-reused 0
# Receiving objects: 100% (553/553), 12.72 MiB | 16.76 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !cp /content/an-pr/ANPR/darknet/data/obj -r /content/darknet/data

# %%
# !cp /content/an-pr/ANPR/darknet/data/obj.data -r /content/darknet/data

# %%
# !cp /content/an-pr/ANPR/darknet/data/obj.names -r /content/darknet/data

# %%
# !cp /content/an-pr/ANPR/darknet/data/train.txt -r /content/darknet/data

# %%
# !cp /content/an-pr/ANPR/darknet/data/val.txt -r /content/darknet/data

# %%
cd ..
# Out:
# /content

# %%
cd darknet
# Out:
# /content/darknet

# %% [markdown]
# ### This cell is from  a previous runtime
# ### Uncomment the two cells below in order to obtain the weights

# %%
#cd ..
#!wget https://pjreddie.com/media/files/darknet53.conv.74
#pwd
#cd darknet

# %%
#!./darknet detector train /content/an-pr/ANPR/darknet/data/obj.data /content/an-pr/ANPR/darknet/cfg/yolov3.cfg /content/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  3228: 0.096100, 0.071709 avg loss, 0.001000 rate, 5.239471 seconds, 206592 images
# Loaded: 0.000042 seconds
#
#  3229: 0.066978, 0.071235 avg loss, 0.001000 rate, 5.234238 seconds, 206656 images
# Loaded: 0.000043 seconds
#  Very small path to the image:
#
#  3230: 0.095110, 0.073623 avg loss, 0.001000 rate, 5.280168 seconds, 206720 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000071 seconds
#
#  3231: 0.076875, 0.073948 avg loss, 0.001000 rate, 2.227759 seconds, 206784 images
# Loaded: 0.000045 seconds
#
#  3232: 0.086757, 0.075229 avg loss, 0.001000 rate, 2.303630 seconds, 206848 images
# Loaded: 0.000071 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3233: 0.063255, 0.074032 avg loss, 0.001000 rate, 2.314604 seconds, 206912 images
# Loaded: 0.000037 seconds
#
# ...

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !cp /content/gdrive/My\ Drive/yolov3_3000.weights -r /content/darknet/

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/an-pr/ANPR/darknet/cfg/yolov3.cfg /content/darknet/yolov3_3000.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# Loaded: 0.000075 seconds
#
#  4786: 0.052436, 0.044408 avg loss, 0.001000 rate, 2.901906 seconds, 306304 images
# Loaded: 0.000069 seconds
#
#  4787: 0.035658, 0.043533 avg loss, 0.001000 rate, 2.888399 seconds, 306368 images
# Loaded: 0.000034 seconds
#
#  4788: 0.033734, 0.042553 avg loss, 0.001000 rate, 2.873384 seconds, 306432 images
# Loaded: 0.000062 seconds
#  Very small path to the image:
#
#  4789: 0.042527, 0.042550 avg loss, 0.001000 rate, 2.905788 seconds, 306496 images
# Loaded: 0.000043 seconds
#  Very small path to the image:
#
#  4790: 0.027899, 0.041085 avg loss, 0.001000 rate, 2.901006 seconds, 306560 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.191196 seconds
#
#  4791: 0.075210, 0.044498 avg loss, 0.001000 rate, 2.231602 seconds, 306624 images
# Loaded: 0.000043 seconds
#
# ...
